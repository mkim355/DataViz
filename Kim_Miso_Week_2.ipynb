# %%
import matplotlib.pyplot as plt

x1, y1 = [1, 5], [1, 3]
x2, y2 = [5, 9], [3, 1]
x3, y3 = [1, 9], [1, 1]


plt.plot(x1, y1, x2, y2, x3, y3, marker = '+', color = "green")
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('Red', 'White', 'Sparkling', 'Rosé', 'Dessert', 'Fortified')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Search')
plt.title('Popular Wine Type')

plt.show()
